# %% [markdown]
# # The Color Palettes are Color-Blind Friendly as categorized by ColorBrewer 2.0

# %% [markdown]
# ### The following palettes can be adopted for contour plots to make python plots more accessible.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Defining a function
def f(x,y):
    return x-y*15/np.exp(x**2 +y**2)

x = np.linspace(-2, 2, 300)
y = np.linspace(-2, 2, 300)
X,Y = np.meshgrid(x, y)

#Plotting a contour with contour lines
#Subplots of order [5x4]
fig,(axs)= plt.subplots(nrows=5,ncols=4,figsize=(15,15),sharex= True, sharey=True)

axs[0,0].contourf(X, Y, f(X, Y), 8, alpha=.75, colors = ('#a6cee3','#1f78b4','#b2df8a','#33a02c','#fbb4b9'))
axs[0,0].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[0,1].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#feebe2','#fbb4b9','#f768a1','#ae017e','#7a0177'))# pinks
axs[0,1].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[0,2].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#f0f9e8','#bae4bc','#7bccc4','#43a2ca','#0868ac'))# blue greens
axs[0,2].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[0,3].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#f1eef6','#d7b5d8','#df65b0','#dd1c77','#980043')) # pink-red
axs[0,3].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[1,0].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#ffffcc','#a1dab4','#41b6c4','#2c7fb8','#253494')) #yellow-dark blue
axs[1,0].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[1,1].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#a6611a','#dfc27d','#f5f5f5','#80cdc1','#018571')) #brown to green
axs[1,1].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[1,2].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#7b3294','#c2a5cf','#f7f7f7','#a6dba0','#008837')) # purple to green
axs[1,2].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[1,3].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#ca0020','#f4a582','#f7f7f7','#92c5de','#0571b0')) # red to blue
axs[1,3].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[2,0].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#f7f7f7','#cccccc','#969696','#636363','#252525')) # black and white
axs[2,0].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[2,1].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#f6eff7','#bdc9e1','#67a9cf','#1c9099','#016c59'))
axs[2,1].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[2,2].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#ffffd4','#fed98e','#fe9929','#d95f0e','#993404')) #orange brown
axs[2,2].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[2,3].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#f1eef6','#bdc9e1','#74a9cf','#2b8cbe','#045a8d')) # cool blues
axs[2,3].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)


axs[3,0].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#F6793A','#A95AA1','#85C0F9','#0F2080')) # ORANGE TO BLUE
axs[3,0].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[3,1].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#AE9C45','#6073B1','#A7B8F8','#052955')) # OLIVE TO BLUE
axs[3,1].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[3,2].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#BDB8AD','#EBE7E0','#C6D4E1','#44749D'))#BLUE GREY
axs[3,2].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[3,3].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#ABC3C9','#E0DCD3','#CCBE9F','#382119'))
axs[3,3].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[4,0].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#104A56','#469AAF','#9ACCD6','#EDE7E3','#FFA62B'))
axs[4,0].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[4,1].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#F4E2CD','#E3BA8C','#C38D46','#916327','#5E3E1D'))
axs[4,1].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)

axs[4,2].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#2E2924','#765F2E','#A07D2C','#EBE6DB','#57534C'))
axs[4,2].contour(X, Y, f(X, Y), colors='black')
plt.clabel(C, inline=1, fontsize=10)
# Out:
# <a list of 7 text.Text objects>

# %%
def f(x,y):
    return x-y*15/np.exp(x**2 +y**2)

x = np.linspace(-2, 2, 300)
y = np.linspace(-2, 2, 300)
X,Y = np.meshgrid(x, y)


#Subplots of order [5x4]
fig,(axs)= plt.subplots(nrows=5,ncols=4,figsize=(15,15),sharex= True, sharey=True)

axs[0,0].contourf(X, Y, f(X, Y), 8, alpha=.75, colors = ('#a6cee3','#1f78b4','#b2df8a','#33a02c','#fbb4b9'))
axs[0,1].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#feebe2','#fbb4b9','#f768a1','#ae017e','#7a0177'))# pinks
axs[0,2].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#f0f9e8','#bae4bc','#7bccc4','#43a2ca','#0868ac'))# blue greens
axs[0,3].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#f1eef6','#d7b5d8','#df65b0','#dd1c77','#980043')) # pink-red
axs[1,0].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#ffffcc','#a1dab4','#41b6c4','#2c7fb8','#253494')) #yellow-dark blue
axs[1,1].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#a6611a','#dfc27d','#f5f5f5','#80cdc1','#018571')) #brown to green
axs[1,2].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#7b3294','#c2a5cf','#f7f7f7','#a6dba0','#008837')) # purple to green
axs[1,3].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#ca0020','#f4a582','#f7f7f7','#92c5de','#0571b0')) # red to blue
axs[2,0].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#f7f7f7','#cccccc','#969696','#636363','#252525')) # black and white
axs[2,1].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#f6eff7','#bdc9e1','#67a9cf','#1c9099','#016c59'))
axs[2,2].contourf(X, Y, f(X, Y), 8, alpha=.75,colors = ('#ffffd4','#fed98e','#fe9929','#d95f0e','#993404')) #orange brown
axs[2,3].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#f1eef6','#bdc9e1','#74a9cf','#2b8cbe','#045a8d')) # cool blues
axs[3,0].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#F6793A','#A95AA1','#85C0F9','#0F2080')) # ORANGE TO BLUE
axs[3,1].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#AE9C45','#6073B1','#A7B8F8','#052955')) # OLIVE TO BLUE
axs[3,2].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#BDB8AD','#EBE7E0','#C6D4E1','#44749D'))#BLUE GREY
axs[3,3].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#ABC3C9','#E0DCD3','#CCBE9F','#382119'))
axs[4,0].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#104A56','#469AAF','#9ACCD6','#EDE7E3','#FFA62B'))
axs[4,1].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#F4E2CD','#E3BA8C','#C38D46','#916327','#5E3E1D'))
axs[4,2].contourf(X, Y, f(X, Y), 8, alpha=.75,colors =('#2E2924','#765F2E','#A07D2C','#EBE6DB','#57534C'))
plt.yticks([])
plt.show()
